# %% [markdown]
# # 3F8 Inference: Coursework
#
# This is the auxiliary code for the 3F8 coursework. Some parts are missing and should be completed by the student. These are marked with `XXX`.

# %% [markdown]
# ## How to Use This Notebook
#
# This notebook is divided into **cells** containing either code or text. To work through the coursework, run each code cell from top to bottom using these keyboard shortcuts:
#
# - **Shift+Enter** — Run the current cell and move to the next one
# - **Ctrl+Enter** — Run the current cell and stay on it (useful for re-running a cell after changing a parameter)
#
# Cells can be run in any order, but each cell may depend on variables or functions defined in earlier cells. When working through the notebook for the first time, it is simplest to run cells from top to bottom. If you go back and change a cell, make sure to re-run it and any later cells that depend on it.
#
# You can use the **+ Code** / **+ Text** buttons that appear below each cell when you hover to add a new cell (useful for experimenting or adding your own notes).

# %% [markdown]
# ## Setup
#
# The coursework requires two data files: `X.txt` and `y.txt`.
#
# **Option 1 (recommended):** Run the cell below to download them automatically from GitHub.

# %%
# import urllib.request

# base_url = "https://raw.githubusercontent.com/cbl-cambridge/3F8-Lab/main/"
# for filename in ["X.txt", "y.txt"]:
#     urllib.request.urlretrieve(base_url + filename, filename)
#     print(f"Downloaded {filename}")

# %% [markdown]
# **Option 2:** Upload the files manually. In Google Colab:
#
# 1. Click the **files icon** (folder) in the left sidebar
# 2. Click the **upload icon** at the top of the file browser
# 3. Select `X.txt` and `y.txt` from your computer
#
# <img src="https://raw.githubusercontent.com/cbl-cambridge/3F8-Lab/main/Colab%20Upload%20Instructions.png" width="300">

# %% [markdown]
# ## Load and Visualise the Data

# %%
# We load the data

import numpy as np

np.random.seed(1)

X = np.loadtxt("X.txt")
y = np.loadtxt("y.txt")

# %%
# We randomly permute the data

permutation = np.random.permutation(X.shape[0])
X = X[permutation, :]
y = y[permutation]

# %%
# We plot the data

import matplotlib.pyplot as plt

##
# Function that plots the points in 2D together with their labels
#
# Inputs:
#
# X: 2d array with the input features
# y: 1d array with the class labels (0 or 1)
#
# Output: 2D matrices with the x and y coordinates of the points shown in the plot
#


def plot_data_internal(X, y):
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    plt.figure()
    plt.xlim(xx.min(None), xx.max(None))
    plt.ylim(yy.min(None), yy.max(None))
    ax = plt.gca()
    ax.plot(X[y == 0, 0], X[y == 0, 1], "ro", label="Class 1")
    ax.plot(X[y == 1, 0], X[y == 1, 1], "bo", label="Class 2")
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.title("Plot data")
    plt.legend(loc="upper left", scatterpoints=1, numpoints=1)
    return xx, yy


##
# Function that plots the data without returning anything by calling "plot_data_internal".
#
# Input:
#
# X: 2d array with the input features
# y: 1d array with the class labels (0 or 1)
#
# Output: Nothing.
#


def plot_data(X, y):
    xx, yy = plot_data_internal(X, y)
    plt.show()

# %% [markdown]
# > **Exercise c)** Visualise the dataset in the two-dimensional input space displaying each datapoint's class label. Discuss how well a classifier with a linear class boundary is likely to perform on these data.

# %%
# Exercise c) - Visualise the dataset and save figure for report
xx, yy = plot_data_internal(X, y)
plt.savefig("figures/data_visualisation.png", bbox_inches="tight", dpi=150)
plt.show()

# %% [markdown]
# ## Train/Test Split and Model Functions

# %%
# We split the data into train and test sets

n_train = 800
X_train = X[0:n_train, :]
X_test = X[n_train:, :]
y_train = y[0:n_train]
y_test = y[n_train:]

# %%
# The logistic function


def logistic(x):
    return 1.0 / (1.0 + np.exp(-x))


##
# Function that makes predictions with a logistic classifier
#
# Input:
#
# X_tile: matrix of input features (with a constant 1 appended to the left)
#         for which to make predictions
# w: vector of model parameters
#
# Output: The predictions of the logistic classifier
#


def predict(X_tilde, w):
    return logistic(np.dot(X_tilde, w))


##
# Function that computes the average loglikelihood of the logistic classifier on some data.
#
# Input:
#
# X_tile: matrix of input features (with a constant 1 appended to the left)
#         for which to make predictions
# y: vector of binary output labels
# w: vector of model parameters
#
# Output: The average loglikelihood
#


def compute_average_ll(X_tilde, y, w):
    output_prob = predict(X_tilde, w)
    return np.mean(y * np.log(output_prob) + (1 - y) * np.log(1.0 - output_prob))


##
# Function that expands a matrix of input features by adding a column equal to 1.
#
# Input:
#
# X: matrix of input features.
#
# Output: Matrix x_tilde with one additional constant column equal to 1 added.
#


def get_x_tilde(X):
    return np.concatenate((np.ones((X.shape[0], 1)), X), 1)

# %% [markdown]
# ## Training the Logistic Classifier

# %%
def fit_w(X_tilde_train, y_train, X_tilde_test, y_test, n_steps, alpha):
    w = np.random.randn(X_tilde_train.shape[1])
    ll_train = np.zeros(n_steps)
    ll_test = np.zeros(n_steps)
    for i in range(n_steps):
        sigmoid_value = predict(X_tilde_train, w)
        # Gradient ascent: w += alpha * X_tilde^T (y - sigma)
        w = w + alpha * np.dot(X_tilde_train.T, y_train - sigmoid_value)

        ll_train[i] = compute_average_ll(X_tilde_train, y_train, w)
        ll_test[i] = compute_average_ll(X_tilde_test, y_test, w)

    return w, ll_train, ll_test

# %%
# Exercise d) - Train the linear logistic classifier

alpha = 0.0005
n_steps = 100

X_tilde_train = get_x_tilde(X_train)
X_tilde_test = get_x_tilde(X_test)
w, ll_train, ll_test = fit_w(
    X_tilde_train, y_train, X_tilde_test, y_test, n_steps, alpha
)

# %% [markdown]
# ## Plotting the Results

# %%
def plot_ll(ll, save_path=None):
    plt.figure()
    ax = plt.gca()
    plt.xlim(0, len(ll) + 2)
    plt.ylim(min(ll) - 0.1, max(ll) + 0.1)
    ax.plot(np.arange(1, len(ll) + 1), ll, "r-")
    plt.xlabel("Steps")
    plt.ylabel("Average log-likelihood")
    plt.title("Plot Average Log-likelihood Curve")
    if save_path:
        plt.savefig(save_path, bbox_inches="tight", dpi=150)
    plt.show()

# %%
# Exercise d) - Plot learning curves
plot_ll(ll_train, save_path="figures/ll_train_linear.png")
plot_ll(ll_test, save_path="figures/ll_test_linear.png")

print(f"Final train ll: {ll_train[-1]:.4f}, Final test ll: {ll_test[-1]:.4f}")
# Out:
# Final train ll: -0.6161, Final test ll: -0.6551

# %%
def plot_predictive_distribution(X, y, w, map_inputs=lambda x: x, save_path=None):
    xx, yy = plot_data_internal(X, y)
    ax = plt.gca()
    X_tilde = get_x_tilde(
        map_inputs(
            np.concatenate(
                (xx.ravel().reshape((-1, 1)), yy.ravel().reshape((-1, 1))), 1
            )
        )
    )
    Z = predict(X_tilde, w)
    Z = Z.reshape(xx.shape)
    cs2 = ax.contour(xx, yy, Z, cmap="RdBu", linewidths=2)
    plt.clabel(cs2, fmt="%2.1f", colors="k", fontsize=14)
    if save_path:
        plt.savefig(save_path, bbox_inches="tight", dpi=150)
    plt.show()

# %%
# Exercise d) - Plot predictive distribution contours
plot_predictive_distribution(X, y, w, save_path="figures/contours_linear.png")

# %% [markdown]
# > **Exercise e)** Report the final training and test log-likelihoods per datapoint. Compute the 2x2 confusion matrix on the test set using threshold $\tau = 0.5$.

# %%
# Exercise e) - Final log-likelihoods and confusion matrix
print(f"Final avg train ll: {ll_train[-1]:.4f}")
print(f"Final avg test ll:  {ll_test[-1]:.4f}")

# Confusion matrix on test set with threshold 0.5
y_pred = (predict(X_tilde_test, w) > 0.5).astype(int)
n_test = len(y_test)

tn = np.mean((y_test == 0) & (y_pred == 0))  # P(y_hat=0 | y=0)
fp = np.mean((y_test == 0) & (y_pred == 1))  # P(y_hat=1 | y=0) -- wrong
fn = np.mean((y_test == 1) & (y_pred == 0))  # P(y_hat=0 | y=1) -- wrong
tp = np.mean((y_test == 1) & (y_pred == 1))  # P(y_hat=1 | y=1)

# Fractions conditioned on true label (as required by coursework)
n0 = np.sum(y_test == 0)
n1 = np.sum(y_test == 1)
tn_rate = np.sum((y_test == 0) & (y_pred == 0)) / n0
fp_rate = np.sum((y_test == 0) & (y_pred == 1)) / n0
fn_rate = np.sum((y_test == 1) & (y_pred == 0)) / n1
tp_rate = np.sum((y_test == 1) & (y_pred == 1)) / n1

print(f"\nConfusion matrix (fractions conditioned on true label):")
print(f"              y_hat=0    y_hat=1")
print(f"  y=0        {tn_rate:.4f}     {fp_rate:.4f}")
print(f"  y=1        {fn_rate:.4f}     {tp_rate:.4f}")
# Out:
# Final avg train ll: -0.6161
# Final avg test ll:  -0.6551
#
# Confusion matrix (fractions conditioned on true label):
#               y_hat=0    y_hat=1
#   y=0        0.6154     0.3846
#   y=1        0.2812     0.7188

# %% [markdown]
# ## Non-Linear Feature Expansion with Radial Basis Functions

# %%
##
# Function that replaces initial input features by evaluating Gaussian basis functions
# on a grid of points
#
# Inputs:
#
# l: hyper-parameter for the width of the Gaussian basis functions
# Z: location of the Gaussian basis functions
# X: points at which to evaluate the basis functions
#
# Output: Feature matrix with the evaluations of the Gaussian basis functions.
#


def evaluate_basis_functions(l, X, Z):
    X2 = np.sum(X**2, 1)
    Z2 = np.sum(Z**2, 1)
    ones_Z = np.ones(Z.shape[0])
    ones_X = np.ones(X.shape[0])
    r2 = np.outer(X2, ones_Z) - 2 * np.dot(X, Z.T) + np.outer(ones_X, Z2)
    return np.exp(-0.5 / l**2 * r2)

# %%
# Exercise f) - Train RBF classifiers for l in {0.01, 0.1, 1}
# Store results for exercise g)
# Smaller l => sharper features => need smaller alpha to avoid divergence
# Larger l => smoother features => can use larger alpha and fewer steps

l_values = [0.01, 0.1, 1.0]
alpha_values = [0.0001, 0.001, 0.00005]
n_steps_values = [500, 500, 500]

rbf_results = {}

for l, alpha_rbf, n_steps_rbf in zip(l_values, alpha_values, n_steps_values):
    print(f"\n--- l = {l}, alpha = {alpha_rbf}, n_steps = {n_steps_rbf} ---")
    X_tilde_train_rbf = get_x_tilde(evaluate_basis_functions(l, X_train, X_train))
    X_tilde_test_rbf = get_x_tilde(evaluate_basis_functions(l, X_test, X_train))

    w_rbf, ll_train_rbf, ll_test_rbf = fit_w(
        X_tilde_train_rbf, y_train, X_tilde_test_rbf, y_test, n_steps_rbf, alpha_rbf
    )

    # Store for exercise g)
    rbf_results[l] = {
        "w": w_rbf,
        "ll_train": ll_train_rbf,
        "ll_test": ll_test_rbf,
        "X_tilde_train": X_tilde_train_rbf,
        "X_tilde_test": X_tilde_test_rbf,
    }

    # Plot learning curves
    plot_ll(ll_train_rbf, save_path=f"figures/ll_train_rbf_{l}.png")
    plot_ll(ll_test_rbf, save_path=f"figures/ll_test_rbf_{l}.png")

    # Plot contours
    plot_predictive_distribution(
        X,
        y,
        w_rbf,
        map_inputs=lambda x, l=l: evaluate_basis_functions(l, x, X_train),
        save_path=f"figures/contours_rbf_{l}.png",
    )

    print(f"Final train ll: {ll_train_rbf[-1]:.4f}, test ll: {ll_test_rbf[-1]:.4f}")
# Out:
# --- l = 0.01, alpha = 0.0001, n_steps = 500 ---
# Final train ll: -0.7907, test ll: -0.6927
#
# --- l = 0.1, alpha = 0.001, n_steps = 500 ---
# Final train ll: -0.2433, test ll: -0.3537
#
# --- l = 1.0, alpha = 5e-05, n_steps = 500 ---
# Final train ll: -0.3676, test ll: -0.4143

# %% [markdown]
# > Demonstration of oscillations when learning rate is too large for $l = 1.0$.
#
# numerical errors start

# %%
# Demonstrate oscillations with too-large learning rate for l=1.0
l_osc = 1.0
alpha_osc = 0.0005
n_steps_osc = 500

X_tilde_train_osc = get_x_tilde(evaluate_basis_functions(l_osc, X_train, X_train))
X_tilde_test_osc = get_x_tilde(evaluate_basis_functions(l_osc, X_test, X_train))

w_osc, ll_train_osc, ll_test_osc = fit_w(
    X_tilde_train_osc, y_train, X_tilde_test_osc, y_test, n_steps_osc, alpha_osc
)

plot_ll(ll_train_osc, save_path="figures/ll_train_rbf_1.0_osc.png")
plot_ll(ll_test_osc, save_path="figures/ll_test_rbf_1.0_osc.png")
print(f"Final train ll: {ll_train_osc[-1]:.4f}, test ll: {ll_test_osc[-1]:.4f}")
# Out:
# /tmp/ipykernel_219237/587087212.py:41: RuntimeWarning: divide by zero encountered in log
#   return np.mean(y * np.log(output_prob) + (1 - y) * np.log(1.0 - output_prob))
# /tmp/ipykernel_219237/587087212.py:41: RuntimeWarning: invalid value encountered in multiply
#   return np.mean(y * np.log(output_prob) + (1 - y) * np.log(1.0 - output_prob))
# Final train ll: -1.7090, test ll: -2.2101

# %% [markdown]
# > **Exercise g)** Report the final training and test log-likelihoods per datapoint and the 2x2 confusion matrices for the three RBF models. Compare to the linear classifier.

# %%
# Exercise g) - Log-likelihoods and confusion matrices for RBF models
n0 = np.sum(y_test == 0)
n1 = np.sum(y_test == 1)

for l in [0.01, 0.1, 1.0]:
    res = rbf_results[l]
    w_rbf = res["w"]
    X_tilde_test_rbf = res["X_tilde_test"]
    X_tilde_train_rbf = res["X_tilde_train"]
    ll_train_rbf = res["ll_train"]
    ll_test_rbf = res["ll_test"]

    y_pred = (predict(X_tilde_test_rbf, w_rbf) > 0.5).astype(int)

    tn_rate = np.sum((y_test == 0) & (y_pred == 0)) / n0
    fp_rate = np.sum((y_test == 0) & (y_pred == 1)) / n0
    fn_rate = np.sum((y_test == 1) & (y_pred == 0)) / n1
    tp_rate = np.sum((y_test == 1) & (y_pred == 1)) / n1

    print(f"--- l = {l} ---")
    print(f"Final avg train ll: {ll_train_rbf[-1]:.4f}")
    print(f"Final avg test ll:  {ll_test_rbf[-1]:.4f}")
    print(f"Confusion matrix (fractions conditioned on true label):")
    print(f"              y_hat=0    y_hat=1")
    print(f"  y=0        {tn_rate:.4f}     {fp_rate:.4f}")
    print(f"  y=1        {fn_rate:.4f}     {tp_rate:.4f}")
    print()
# Out:
# --- l = 0.01 ---
# Final avg train ll: -0.7907
# Final avg test ll:  -0.6927
# Confusion matrix (fractions conditioned on true label):
#               y_hat=0    y_hat=1
#   y=0        0.9615     0.0385
#   y=1        0.9167     0.0833
#
# --- l = 0.1 ---
# Final avg train ll: -0.2433
# Final avg test ll:  -0.3537
# Confusion matrix (fractions conditioned on true label):
#               y_hat=0    y_hat=1
#   y=0        0.9327     0.0673
#   y=1        0.2083     0.7917
#
# --- l = 1.0 ---
# Final avg train ll: -0.3676
# Final avg test ll:  -0.4143
# Confusion matrix (fractions conditioned on true label):
#               y_hat=0    y_hat=1
#   y=0        0.7885     0.2115
#   y=1        0.1250     0.8750
